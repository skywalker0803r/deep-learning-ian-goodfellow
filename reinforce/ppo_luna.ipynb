# %% [markdown]
# <a href="https://colab.research.google.com/github/skywalker0803r/deep-learning-ian-goodfellow/blob/master/reinforce/ppo_luna.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import gym
import matplotlib.pyplot as plt
import pandas as pd

url = 'https://gist.githubusercontent.com/skywalker0803r/c363d8b2cf72a8aee06bc238a355fa01/raw/3797321a44871d7285113e4b277d88f18d80169e/PPO.py'
exec(requests.get(url).text)
env = gym.make("LunarLander-v2")
env.seed(seed)
agent = PPOAgent(env)
history = agent.train(max_episodes=1000)
plt.plot(history)
plt.plot(pd.Series(history).rolling(10).mean())
# Out:
# Episode 0: -258.7861394772525
# Episode 1: -525.8807147616662
# Episode 2: -118.29769283709317
# Episode 3: -366.96486231748366
# Episode 4: -79.9761476135567
# Episode 5: -126.8362068488048
# Episode 6: -147.67317624004943
# Episode 7: -350.1569322844191
# Episode 8: -418.0918881677248
# Episode 9: -88.6626192347006
# Episode 10: -146.38550180384897
# Episode 11: -143.5091990680982
# Episode 12: -176.6864043067684
# Episode 13: -105.5656423596361
# Episode 14: -338.6637005748188
# Episode 15: -184.45940060581304
# Episode 16: -188.80318658063607
# Episode 17: -511.876684622944
# Episode 18: -390.7511649659411
# Episode 19: -101.66434917903413
# Episode 20: -639.9322241987164
# Episode 21: -98.43426680519015
# Episode 22: -67.39622551584314
# Episode 23: -212.87989689605337
# Episode 24: -149.7802658838598
# Episode 25: -120.6190492924471
# Episode 26: -162.77186655708505
# Episode 27: -145.2534965638979
# Episode 28: -216.51752537737954
# Episode 29: -239.33724911407208
# ...
