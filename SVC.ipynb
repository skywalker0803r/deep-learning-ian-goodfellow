# %% [markdown]
# <a href="https://colab.research.google.com/github/skywalker0803r/deep-learning-ian-goodfellow/blob/master/SVC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from numpy.linalg import inv

c1 = np.random.normal(loc=1.5,size=(100,2))
y1 = np.array([1]*c1.shape[0])
c2 = np.random.normal(loc=-1.5,size=(100,2))
y2 = np.array([-1]*c2.shape[0])

# %%
x = np.vstack((c1,c2))
y = np.hstack((y1,y2))

# %%
import matplotlib.pyplot as plt

plt.scatter(x[:,0],x[:,1],c=y,edgecolors='black')
plt.show()

# %%
from sklearn.svm import SVC
model = SVC(C=1,kernel='linear')
model.fit(x,y)
# Out:
# SVC(C=1, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='linear',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
h = .02
x_min, x_max = x[:, 0].min() - 1, x[:, 0].max() + 1
y_min, y_max = x[:, 1].min() - 1, x[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),np.arange(y_min, y_max, h))

# %%
Z = model.predict(np.c_[xx.ravel(), yy.ravel()]).reshape(xx.shape)
plt.contourf(xx, yy, Z, cmap=plt.cm.Paired)
plt.scatter(x[:, 0],x[:, 1], c=y, edgecolors='black')
plt.scatter(model.support_vectors_[:,0],model.support_vectors_[:,1],c='red')
plt.show()
